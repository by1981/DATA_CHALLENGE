# %%
import json
import requests
import pandas as pd
from config import api_key
import random
import citipy
import openweathermapy.core as owm
import numpy as np
units='imperial'
import matplotlib.pyplot as plt
import urllib

# %%
#Selecting Random Latitudes And Longitudes
Latitude=[]
Longitude=[]
for x in range(15000):
    Latitude.append(random.uniform(-90,90))
for x in range(15000):
    Longitude.append(random.uniform(-180,180))

# %%
#Extract City Name, Country Code Using CitiPy 
url='http://api.openweathermap.org/data/2.5/weather?'

query_urllist=[]
lat_random=[]
long_random=[]
city_namelist=[]
country_codelist=[]
  
for i in range(10000):

    cityname=(citipy.nearest_city(Latitude[i], Longitude[i]))
    city_namelist.append(cityname.city_name)
    lat_random.append(Latitude[i])
    long_random.append(Longitude[i])
    country_codelist.append(cityname.country_code)
    
city_dict={ 'City':city_namelist,
            'Country Code':country_codelist,
            'Latitude': lat_random,
            'Longitude': long_random
          }
city_dict_df=pd.DataFrame(city_dict)
city_dict_df=city_dict_df.drop_duplicates(["City"])
city_dict_df=city_dict_df.reset_index(drop=True)
print(len(city_dict_df))
# for i in range(len(city_dict_df)):
#     query_url=f"{url}appid={api_key}&units={units}&q="
#     query_urllist.append(query_url+city_dict_df['City'][i].replace(" ", "%20"))
city_dict_df.head()

city_namelist=city_dict_df["City"]
# Out:
# 2280

# %%
temp=[]
humid=[]
cloud=[]
wind=[]
lat=[]
country=[]
date=[]
lng=[]
max_temp=[]
city=[]

for i, city_value in enumerate(city_namelist):
    query_url= url+"&appid="+api_key+"&units="+units+"&q="+urllib.request.pathname2url(city_value)
    
    try:
        response = requests.get(query_url).json()   
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        city.append(response['name'])
        date.append(response['dt'])
        max_temp.append(response['main']['temp_max'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        cloud.append(response['clouds']['all'])
        print(f"Processing Record {i}: {city_value}")
    except:
        print(city_value + f" not found")
        pass
    if len(city)==500:
        break
# Out:
# Processing Record 0: port-gentil
# Processing Record 1: coquimbo
# taolanaro not found
# Processing Record 3: kapaa
# Processing Record 4: busselton
# Processing Record 5: saint-philippe
# Processing Record 6: thompson
# belushya guba not found
# Processing Record 8: punta arenas
# Processing Record 9: alofi
# Processing Record 10: longyearbyen
# Processing Record 11: victoria
# Processing Record 12: myatlevo
# bur gabo not found
# Processing Record 14: tshikapa
# Processing Record 15: pisco
# Processing Record 16: ushuaia
# Processing Record 17: tocopilla
# Processing Record 18: saskylakh
# Processing Record 19: hilo
# Processing Record 20: mataura
# Processing Record 21: quartucciu
# Processing Record 22: tuatapere
# Processing Record 23: bafq
# Processing Record 24: atuona
# Processing Record 25: bethel
# Processing Record 26: saint-georges
# Processing Record 27: havelock
# Processing Record 28: pevek
# Processing Record 29: erzin
# Processing Record 30: souillac
# Processing Record 31: esperance
# Processing Record 32: senno
# Processing Record 33: cabo san lucas
# acarau not found
# Processing Record 35: warah
# Processing Record 36: bluff
# Processing Record 37: lebu
# Processing Record 38: sao filipe
# tasbuget not found
# Processing Record 40: rikitea
# halalo not found
# Processing Record 42: katsuura
# Processing Record 43: castro
# Processing Record 44: maues
# Processing Record 45: bredasdorp
# Processing Record 46: yulara
# Processing Record 47: vaini
# Processing Record 48: berlin
# Processing Record 49: severo-kurilsk
# Processing Record 50: srednekolymsk
# Processing Record 51: north bend
# babanusah not found
# Processing Record 53: ugoofaaru
# Processing Record 54: mbanza-ngungu
# Processing Record 55: port alfred
# Processing Record 56: santona
# Processing Record 57: kavaratti
# Processing Record 58: namibe
# Processing Record 59: cidreira
# sembe not found
# Processing Record 61: pundaguitan
# Processing Record 62: singkang
# taburi not found
# Processing Record 64: pochutla
# Processing Record 65: barrow
# Processing Record 66: dunedin
# Processing Record 67: namikupa
# Processing Record 68: sibolga
# Processing Record 69: los llanos de aridane
# Processing Record 70: vao
# Processing Record 71: upernavik
# amderma not found
# Processing Record 73: contamana
# Processing Record 74: carnarvon
# Processing Record 75: isangel
# Processing Record 76: pascagoula
# Processing Record 77: grande prairie
# Processing Record 78: hajnowka
# Processing Record 79: qaanaaq
# illoqqortoormiut not found
# Processing Record 81: hobyo
# Processing Record 82: channel-port aux basques
# Processing Record 83: new norfolk
# Processing Record 84: namtsy
# Processing Record 85: saldanha
# Processing Record 86: buala
# Processing Record 87: sechura
# Processing Record 88: khatanga
# Processing Record 89: fergus falls
# Processing Record 90: clyde river
# Processing Record 91: sitka
# Processing Record 92: palmer
# Processing Record 93: sindou
# Processing Record 94: aklavik
# Processing Record 95: chapais
# Processing Record 96: lasa
# Processing Record 97: albany
# Processing Record 98: airai
# Processing Record 99: garissa
# Processing Record 100: whithorn
# Processing Record 101: lazi
# Processing Record 102: burnie
# Processing Record 103: hamilton
# Processing Record 104: nikolskoye
# Processing Record 105: rocha
# envira not found
# Processing Record 107: mahebourg
# Processing Record 108: avarua
# Processing Record 109: skala
# mullaitivu not found
# Processing Record 111: norman wells
# Processing Record 112: cape town
# Processing Record 113: kautokeino
# Processing Record 114: patti
# korla not found
# Processing Record 116: kodiak
# Processing Record 117: port elizabeth
# Processing Record 118: vagur
# utiroa not found
# Processing Record 120: tamala
# Processing Record 121: atambua
# Processing Record 122: guerrero negro
# Processing Record 123: laguna
# Processing Record 124: kulu
# Processing Record 125: hermanus
# Processing Record 126: beitbridge
# Processing Record 127: chokurdakh
# Processing Record 128: dali
# Processing Record 129: amahai
# Processing Record 130: winnemucca
# Processing Record 131: hobart
# Processing Record 132: kudahuvadhoo
# Processing Record 133: tasiilaq
# Processing Record 134: port blair
# Processing Record 135: godda
# Processing Record 136: butaritari
# Processing Record 137: klaksvik
# Processing Record 138: hithadhoo
# Processing Record 139: torbay
# Processing Record 140: georgetown
# Processing Record 141: cairns
# Processing Record 142: mitsamiouli
# Processing Record 143: lavrentiya
# Processing Record 144: niamey
# Processing Record 145: codrington
# Processing Record 146: mar del plata
# Processing Record 147: kirakira
# Processing Record 148: nouadhibou
# mys shmidta not found
# Processing Record 150: puerto baquerizo moreno
# Processing Record 151: aykhal
# Processing Record 152: araouane
# Processing Record 153: sartana
# Processing Record 154: furano
# Processing Record 155: zaterechnyy
# Processing Record 156: brigantine
# Processing Record 157: flin flon
# Processing Record 158: dikson
# Processing Record 159: vieksniai
# Processing Record 160: ambilobe
# Processing Record 161: ribeira grande
# Processing Record 162: kibaya
# Processing Record 163: pimenta bueno
# Processing Record 164: puerto ayora
# Processing Record 165: bathsheba
# Processing Record 166: cherskiy
# Processing Record 167: vardo
# Processing Record 168: nkayi
# Processing Record 169: trairi
# Processing Record 170: weyburn
# Processing Record 171: tigil
# Processing Record 172: iqaluit
# Processing Record 173: parabel
# Processing Record 174: touros
# Processing Record 175: constitucion
# Processing Record 176: tiarei
# Processing Record 177: apac
# Processing Record 178: saint-pierre
# Processing Record 179: yuli
# Processing Record 180: qaqortoq
# Processing Record 181: ponta do sol
# Processing Record 182: salalah
# Processing Record 183: padang
# umm durman not found
# Processing Record 185: monki
# Processing Record 186: altay
# Processing Record 187: segezha
# Processing Record 188: boueni
# nizhneyansk not found
# Processing Record 190: pocoes
# Processing Record 191: samana
# Processing Record 192: chik
# Processing Record 193: college
# Processing Record 194: ancud
# barentsburg not found
# Processing Record 196: mehamn
# Processing Record 197: chapada dos guimaraes
# Processing Record 198: beaufort
# Processing Record 199: belaya gora
# Processing Record 200: owo
# Processing Record 201: kiama
# Processing Record 202: bad sassendorf
# Processing Record 203: sao joao da barra
# Processing Record 204: narsaq
# Processing Record 205: duluth
# Processing Record 206: daru
# Processing Record 207: haines junction
# Processing Record 208: east london
# juifang not found
# fevralsk not found
# Processing Record 211: geraldton
# Processing Record 212: peniche
# Processing Record 213: kavieng
# Processing Record 214: sabla
# Processing Record 215: naze
# Processing Record 216: ahipara
# Processing Record 217: lompoc
# Processing Record 218: labuhan
# Processing Record 219: honningsvag
# Processing Record 220: malokaterynivka
# balykshi not found
# Processing Record 222: sola
# Processing Record 223: nuuk
# Processing Record 224: newton
# Processing Record 225: guamuchil
# Processing Record 226: gao
# Processing Record 227: egvekinot
# tsihombe not found
# Processing Record 229: poronaysk
# Processing Record 230: voyvozh
# Processing Record 231: praya
# Processing Record 232: praia
# vastervik not found
# yirol not found
# Processing Record 235: coihaique
# vylgort not found
# vila franca do campo not found
# Processing Record 238: brikama
# Processing Record 239: wahiawa
# Processing Record 240: fortuna
# Processing Record 241: arraial do cabo
# Processing Record 242: adrar
# Processing Record 243: iralaya
# Processing Record 244: yellowknife
# Processing Record 245: port hardy
# Processing Record 246: terrace bay
# Processing Record 247: atar
# Processing Record 248: antequera
# ardistan not found
# Processing Record 250: filadelfia
# Processing Record 251: kingaroy
# Processing Record 252: dinan
# Processing Record 253: mount gambier
# krasnoselkup not found
# Processing Record 255: wajir
# Processing Record 256: tessalit
# Processing Record 257: tuktoyaktuk
# akyab not found
# Processing Record 259: sarangani
# Processing Record 260: rongcheng
# Processing Record 261: roebourne
# Processing Record 262: san quintin
# Processing Record 263: caravelas
# Processing Record 264: sorland
# Processing Record 265: zhicheng
# jiddah not found
# Processing Record 267: broome
# Processing Record 268: nichinan
# Processing Record 269: malmo
# Processing Record 270: castellammare del golfo
# Processing Record 271: lagoa
# Processing Record 272: christchurch
# Processing Record 273: meulaboh
# Processing Record 274: makakilo city
# Processing Record 275: ust-koksa
# Processing Record 276: mogadishu
# Processing Record 277: ostrovnoy
# Processing Record 278: athabasca
# Processing Record 279: ornskoldsvik
# Processing Record 280: kundiawa
# Processing Record 281: karratha
# Processing Record 282: udachnyy
# Processing Record 283: sioux lookout
# Processing Record 284: antofagasta
# Processing Record 285: kamenka
# Processing Record 286: talcahuano
# Processing Record 287: biak
# Processing Record 288: san vicente de canete
# Processing Record 289: colotlan
# Processing Record 290: harnosand
# Processing Record 291: oranjestad
# Processing Record 292: ternate
# Processing Record 293: bhunya
# Processing Record 294: sao caetano de odivelas
# Processing Record 295: evensk
# Processing Record 296: nador
# Processing Record 297: stende
# Processing Record 298: sistranda
# Processing Record 299: russell
# Processing Record 300: vicente guerrero
# bentiu not found
# Processing Record 302: mayahi
# Processing Record 303: puerto ayacucho
# Processing Record 304: barcelos
# asau not found
# dolbeau not found
# Processing Record 307: chimbote
# Processing Record 308: santa isabel do rio negro
# Processing Record 309: talnakh
# Processing Record 310: jamestown
# Processing Record 311: saint george
# Processing Record 312: buchanan
# Processing Record 313: axim
# Processing Record 314: phonhong
# tapaua not found
# Processing Record 316: buchlovice
# Processing Record 317: dongsheng
# raga not found
# Processing Record 319: angoche
# Processing Record 320: bilibino
# Processing Record 321: port lincoln
# Processing Record 322: pindiga
# Processing Record 323: cayenne
# Processing Record 324: umm lajj
# blonduos not found
# Processing Record 326: sabang
# malwan not found
# Processing Record 328: peterhead
# Processing Record 329: farafangana
# Processing Record 330: salinas
# Processing Record 331: kununurra
# Processing Record 332: plouzane
# Processing Record 333: high rock
# da nang not found
# Processing Record 335: tamale
# Processing Record 336: harper
# Processing Record 337: rio gallegos
# Processing Record 338: san patricio
# Processing Record 339: fairbanks
# Processing Record 340: tanout
# Processing Record 341: tagusao
# Processing Record 342: mweka
# Processing Record 343: kieta
# Processing Record 344: taksimo
# Processing Record 345: taltal
# Processing Record 346: comodoro rivadavia
# Processing Record 347: yuci
# Processing Record 348: husavik
# Processing Record 349: te anau
# Processing Record 350: praia da vitoria
# Processing Record 351: denpasar
# Processing Record 352: tomatlan
# Processing Record 353: bambanglipuro
# Processing Record 354: rio brilhante
# Processing Record 355: mirnyy
# Processing Record 356: lamphun
# Processing Record 357: hasaki
# Processing Record 358: beringovskiy
# Processing Record 359: ocos
# Processing Record 360: sept-iles
# Processing Record 361: tokmak
# Processing Record 362: chernyshevskiy
# Processing Record 363: huntingdon
# Processing Record 364: ixtapa
# Processing Record 365: saint-leu
# Processing Record 366: itarema
# Processing Record 367: polikhronon
# Processing Record 368: trincomalee
# Processing Record 369: chuy
# Processing Record 370: butterworth
# Processing Record 371: shimanovsk
# Processing Record 372: tateyama
# inderborskiy not found
# Processing Record 374: lagoa vermelha
# Processing Record 375: stromness
# Processing Record 376: bereda
# Processing Record 377: zhigansk
# Processing Record 378: tabory
# Processing Record 379: ulaanbaatar
# Processing Record 380: hohhot
# Processing Record 381: rawson
# Processing Record 382: washougal
# attawapiskat not found
# Processing Record 384: yabassi
# Processing Record 385: whitianga
# Processing Record 386: ajdabiya
# Processing Record 387: marzuq
# Processing Record 388: leh
# Processing Record 389: broken hill
# Processing Record 390: port shepstone
# Processing Record 391: gat
# Processing Record 392: guantanamo
# Processing Record 393: pangnirtung
# Processing Record 394: muros
# Processing Record 395: paamiut
# Processing Record 396: provideniya
# Processing Record 397: yumen
# Processing Record 398: newport
# Processing Record 399: sisimiut
# Processing Record 400: ayagoz
# Processing Record 401: coahuayana
# Processing Record 402: kalat
# Processing Record 403: rio piracicaba
# Processing Record 404: marystown
# Processing Record 405: ewa beach
# Processing Record 406: namatanai
# Processing Record 407: musashino
# Processing Record 408: svetlaya
# Processing Record 409: mount isa
# Processing Record 410: turbat
# Processing Record 411: monze
# Processing Record 412: nacogdoches
# Processing Record 413: shu
# igarape-miri not found
# Processing Record 415: el alto
# Processing Record 416: navahrudak
# Processing Record 417: parfenyevo
# Processing Record 418: leningradskiy
# Processing Record 419: oksfjord
# Processing Record 420: port hedland
# Processing Record 421: tezu
# Processing Record 422: sur
# Processing Record 423: bonaventure
# Processing Record 424: hualmay
# Processing Record 425: khonsa
# ndele not found
# Processing Record 427: beloha
# Processing Record 428: shirokiy
# Processing Record 429: horasan
# Processing Record 430: mahuva
# Processing Record 431: iskateley
# louisbourg not found
# Processing Record 433: atherton
# viligili not found
# Processing Record 435: hit
# saleaula not found
# Processing Record 437: prachuap khiri khan
# alotau not found
# Processing Record 439: pochinok
# Processing Record 440: kaffrine
# Processing Record 441: greencastle
# Processing Record 442: ilulissat
# bolungarvik not found
# Processing Record 444: dingle
# Processing Record 445: lerwick
# Processing Record 446: nanortalik
# Processing Record 447: diu
# Processing Record 448: avera
# Processing Record 449: lyaskelya
# Processing Record 450: rundu
# Processing Record 451: jiayuguan
# Processing Record 452: llanes
# Processing Record 453: salme
# Processing Record 454: faanui
# mocambique not found
# kemijarvi not found
# Processing Record 457: kampong thum
# Processing Record 458: saint-imier
# Processing Record 459: slobozia
# Processing Record 460: bitung
# bolshegrivskoye not found
# Processing Record 462: luderitz
# Processing Record 463: jatai
# Processing Record 464: stokmarknes
# Processing Record 465: ochamchira
# Processing Record 466: chicama
# Processing Record 467: vilnius
# samusu not found
# Processing Record 469: roxas
# Processing Record 470: mujiayingzi
# Processing Record 471: pontianak
# Processing Record 472: naron
# Processing Record 473: kaitangata
# Processing Record 474: flagstaff
# Processing Record 475: vila velha
# Processing Record 476: arica
# Processing Record 477: emba
# marcona not found
# Processing Record 479: dalbandin
# Processing Record 480: boguchany
# Processing Record 481: tooele
# Processing Record 482: vysokogornyy
# Processing Record 483: bauchi
# Processing Record 484: waingapu
# Processing Record 485: port macquarie
# Processing Record 486: masuguru
# Processing Record 487: bambous virieux
# zhemchuzhnyy not found
# Processing Record 489: alyangula
# Processing Record 490: bubaque
# Processing Record 491: shahr-e babak
# eskasem not found
# Processing Record 493: cap malheureux
# Processing Record 494: gardez
# bac lieu not found
# Processing Record 496: quesnel
# Processing Record 497: listvyanskiy
# Processing Record 498: ambon
# Processing Record 499: alice springs
# Processing Record 500: rantauprapat
# Processing Record 501: lahij
# Processing Record 502: woodward
# Processing Record 503: shingu
# tonj not found
# Processing Record 505: valparaiso
# Processing Record 506: zhigalovo
# Processing Record 507: voznesenye
# Processing Record 508: rayagada
# Processing Record 509: newberry
# Processing Record 510: auki
# Processing Record 511: san luis
# Processing Record 512: mamallapuram
# palabuhanratu not found
# khonuu not found
# Processing Record 515: mayumba
# Processing Record 516: opuwo
# Processing Record 517: brae
# Processing Record 518: tomari
# Processing Record 519: yanam
# Processing Record 520: hede
# Processing Record 521: douglas
# Processing Record 522: santa cruz
# Processing Record 523: flinders
# Processing Record 524: nara
# Processing Record 525: bonavista
# Processing Record 526: shepsi
# Processing Record 527: bone
# Processing Record 528: bandarbeyla
# Processing Record 529: panguna
# Processing Record 530: pizhanka
# Processing Record 531: basco
# Processing Record 532: nhulunbuy
# Processing Record 533: yuanping
# Processing Record 534: svetlogorsk
# Processing Record 535: kahului
# Processing Record 536: matagami
# Processing Record 537: saint-paul
# Processing Record 538: mahanoro
# Processing Record 539: mustvee
# Processing Record 540: mikhaylovka
# Processing Record 541: massaguet
# Processing Record 542: piacabucu
# Processing Record 543: jalu
# Processing Record 544: camargo
# Processing Record 545: yangshe
# Processing Record 546: gizo
# Processing Record 547: launceston
# Processing Record 548: samarai
# Processing Record 549: puerto colombia
# Processing Record 550: moa
# Processing Record 551: shimoni
# addi ugri not found
# Processing Record 553: plettenberg bay
# Processing Record 554: teguise
# kashi not found
# Processing Record 556: cururupu
# Processing Record 557: havoysund
# Processing Record 558: mackay
# Processing Record 559: rio grande
# Processing Record 560: novo aripuana

# %%
# temp=[]
# humid=[]
# cloud=[]
# wind=[]
# lat=[]
# country=[]
# date=[]
# lng=[]
# max_temp=[]
# city=[]

# for i in range(len(city_dict_df)):
#     try:
        
#         response = requests.get(query_urllist[i]).json()   
#         lat.append(response['coord']['lat'])
#         lng.append(response['coord']['lon'])
#         country.append(response['sys']['country'])
#         city.append(response['name'])
#         date.append(response['dt'])
#         max_temp.append(response['main']['temp_max'])
#         temp.append(response['main']['temp'])
#         humid.append(response['main']['humidity'])
#         wind.append(response['wind']['speed'])
#         cloud.append(response['clouds']['all'])
#         recording=recording+1
#         print(f"Processing Record:"+response['name'])
#         #print(response['name'])
#     except:
#         print(f"Not Found:"+)
#         pass
#     if len(city)==500:
#         break
# city

# %%
weather_dict={'City':city,
            "Lat": lat,
            "Temp": temp,
            "Humidity": humid,
            "Wind Speed": wind,
            "Cloudiness": cloud,
            "Lng":lng,
            "Date":date,
            "Country":country,
            "Max Temp":max_temp
             }
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Port-Gentil          92      GA  1522643291       100  -0.72    8.78
# 1        Coquimbo          90      CL  1522641600        87 -29.95  -71.34
# 2           Kapaa           1      US  1522641360        78  22.08 -159.32
# 3       Busselton           0      AU  1522643383        95 -33.64  115.35
# 4  Saint-Philippe          90      CA  1522642500        50  45.36  -73.48
#
#    Max Temp   Temp  Wind Speed
# 0     78.13  78.13        6.04
# 1     57.20  57.20        2.24
# 2     77.00  75.06        6.93
# 3     69.58  69.58       14.54
# 4     32.00  30.18        6.93

# %%
#City Latitude vs Max Temperature

plt.scatter(weather_data['Lat'], weather_data['Max Temp'],facecolors='blue', edgecolors='black', alpha=0.75 )

plt.grid()
#plt.set_facecolor("lightslategray")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.ylim(-100,150)
plt.xlim(-80,100)
plt.title("City Latitude vs Max Temperature")#+ "("+weather_data['Date']+")")
# Out:
# Text(0.5,1,'City Latitude vs Max Temperature')

# %%
#City Latitude vs Humidity
plt.scatter(weather_data['Lat'], weather_data['Humidity'],facecolors='blue', edgecolors='black', alpha=0.75 )

plt.grid()
#plt.set_facecolor("lightslategray")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.ylim(-20,120)
plt.xlim(-80,100)
plt.title("City Latitude vs Humidity")#+ "("+weather_data['Date']+")")
# Out:
# Text(0.5,1,'City Latitude vs Humidity')

# %%
#Latitude vs Cloudiness
plt.scatter(weather_data['Lat'], weather_data['Cloudiness'],facecolors='blue', edgecolors='black', alpha=0.75 )

plt.grid()
#plt.set_facecolor("lightslategray")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.ylim(-20,120)
plt.xlim(-80,100)
plt.title("City Latitude vs Cloudiness")
# Out:
# Text(0.5,1,'City Latitude vs Cloudiness')

# %%
#Latitude vs Wind Speed
plt.scatter(weather_data['Lat'], weather_data['Wind Speed'],facecolors='blue', edgecolors='black', alpha=0.75 )

plt.grid()
#plt.set_facecolor("lightslategray")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-5,40)
plt.xlim(-80,100)
plt.title("City Latitude vs Cloudiness")#+ "("+weather_data['Date']+")")
# Out:
# Text(0.5,1,'City Latitude vs Cloudiness')

# %%
weather_data.to_csv("Weather_Report.csv", encoding='utf-8')
